# %% [markdown]
# # Baseline Models

# %%
##############################################################################################################################
# Load Data
##############################################################################################################################

#==================================================================
# Import Standard Libraries
#==================================================================

from theory_of_mind import *

# Set global parameters
TEMPERATURE = 1
EPOCHS = 20

#==================================================================
# Set Up Data Manager
#==================================================================

dm = DataManager()

bert = dm.load_all_data("bert", True)
print("bert embeddings loaded...")

use = dm.load_all_data("use", False)
print("use embeddings loaded...")

#==================================================================
# Load Labels
#==================================================================

labels = dm.load_all_labels()

#==================================================================
# Format Data
#==================================================================

def concatenate_inputs(df):
    '''Creates concatenated input for word embeddings.'''
    sentences = cc([df["sentence1"], df["sentence2"]])
    difference = df["sentence1"] - df["sentence2"]
    product = np.multiply(df["sentence1"], df["sentence2"])
    return cc([sentences, difference, product])

def format_data_for_training(data, labels):
    '''Returns data and labels for training.'''

    # Transform data
    trD = concatenate_inputs(data["train"])
    evD = concatenate_inputs(data["dev"])

    # Transform labels
    trL = labels["train"]
    evL = labels["dev"]

    print("Training Label Shape: {}".format(trL.shape))
    print("Eval Label Shape: {}".format(evL.shape))
    print("Training Data Shape: {}".format(trD.shape))
    print("Eval Data Shape: {}".format(evL.shape))

    return trD, trL, evD, evL

# Format data
trD_use, trL, evD_use, evL = format_data_for_training(use, labels)
trD_bert, trL, evD_bert, evL = format_data_for_training(bert, labels)
# Out:
# Using TensorFlow backend.
# bert embeddings loaded...
# use embeddings loaded...
# Training Label Shape: (78734, 3)
# Eval Label Shape: (9842, 3)
# Training Data Shape: (78734, 2048)
# Eval Data Shape: (9842, 3)
# Training Label Shape: (78734, 3)
# Eval Label Shape: (9842, 3)
# Training Data Shape: (78734, 3072)
# Eval Data Shape: (9842, 3)

# %%
def build_default_model(name, trD, trL, evD, evL):
    '''Builds and compiles a default model.'''
    
    # Initial layers
    inputs = layers.Input(shape= trD.shape[1])
    outputs = add_layer_for_dense(inputs, name, trD.shape[1])
    
    # Add "partition layer" for easy splitting
    outputs = layers.Lambda(lambda x: x, name = "partition")(outputs)
    
    # Add final layer then compile
    outputs = add_layer_for_dense(outputs, name, 256)
    outputs = layers.Dense(trL.shape[1], name = "logits")(outputs)
    outputs = layers.Activation('softmax', name='softmax')(outputs)
    model = compile_model(name, inputs, outputs)
    
    # Add data as attributes
    model.trD_ = trD
    model.evD_ = evD
    model.trL_ = trL
    model.evL_ = evL
    model.status_ = "..."
    model.save_name_ = model.name_
    
    return model


def fit_model(model, epochs = 5):
    '''Fits model with training and validation data.'''
    
    banner("Running model {}...".format(model.name_), symbol = "=")
    
    history = model.fit(model.trD_, 
                        model.trL_, 
                        validation_data=[model.evD_, model.evL_], 
                        batch_size = 32,
                        epochs=epochs, 
                        verbose=1)
    return history
    
def compile_model(name, inputs, outputs, 
                  loss = 'categorical_crossentropy', 
                  optimizer = 'adam',  
                  metrics = ['accuracy']):
    '''Compiles model. Set as function to preserve defaults.'''
    
    model = keras.models.Model(inputs = inputs, outputs = outputs, name = name)
    model.name_ = model.name
    
    model.compile(loss = loss,  
                  optimizer = optimizer, 
                  metrics = metrics)
    return model

# Add data as attributes
def add_attributes(model, name, trD, trL, evD, evL):
    model.name_ = name
    model.trD_ = trD
    model.evD_ = evD
    model.trL_ = trL
    model.evL_ = evL
    model.status_ = "..."
    model.save_name_ = model.name_
    return model

def save_model_and_history(model, fp = "Final Project/models/"):
    '''Saves model and history.'''
    
    banner("Saving model {}...".format(model.name_))
    
    # Save model
    model.save("{}{}".format(fp, model.save_name_))
    
    # Save history
    history = pd.DataFrame(model.history.history)
    history.to_pickle("{}{}_history.pkl".format(fp, model.save_name_))
    
def load_model_and_history(model_name):
    '''Loads model and its history'''
    model = tf.keras.models.load_model("Final Project/models/{}".format(model_name))
    history = pd.read_pickle("Final Project/models/{}_history.pkl".format(model_name))
    return model, history

# %% [markdown]
# # Baseline Models (Zero-Order Theory of Mind)
#
# Here we run and save models that try to capture the true state of the world.

# %%
#==================================================================
# Universal Sentence Encoder Baseline
#==================================================================

use0 = build_default_model("use_baseline", trD_use, trL, evD_use, evL)
history = fit_model(use0, epochs = 20)
save_model_and_history(use0)

# %% [markdown]
# # Baseline (DistilBert)

# %%
#==================================================================
# Format Data
#==================================================================

bert0 = build_default_model("bert_baseline", trD_bert, trL, evD_bert, evL)
fit_model(bert0, epochs = 20)
save_model_and_history(bert0)
# Out:
# ================================================================================
# Running model bert_baseline...
# ================================================================================
#
# Epoch 1/20
# 2461/2461 [==============================] - 260s 106ms/step - loss: 1.4943 - accuracy: 0.5270 - val_loss: 0.1732 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 2461/2461 [==============================] - 282s 115ms/step - loss: 1.0705 - accuracy: 0.5671 - val_loss: 0.1280 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 2461/2461 [==============================] - 306s 124ms/step - loss: 1.0377 - accuracy: 0.5803 - val_loss: 0.1233 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 2461/2461 [==============================] - 306s 124ms/step - loss: 1.0132 - accuracy: 0.5901 - val_loss: 0.1103 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 2461/2461 [==============================] - 306s 124ms/step - loss: 0.9875 - accuracy: 0.5928 - val_loss: 0.0872 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 2461/2461 [==============================] - 306s 124ms/step - loss: 0.9543 - accuracy: 0.6031 - val_loss: 0.0762 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 2461/2461 [==============================] - 305s 124ms/step - loss: 0.9446 - accuracy: 0.6037 - val_loss: 0.0703 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 2461/2461 [==============================] - 306s 124ms/step - loss: 0.9421 - accuracy: 0.6009 - val_loss: 0.0629 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 2461/2461 [==============================] - 307s 125ms/step - loss: 0.9317 - accuracy: 0.6038 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 2461/2461 [==============================] - 306s 124ms/step - loss: 0.9235 - accuracy: 0.6088 - val_loss: 0.0563 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 2461/2461 [==============================] - 306s 125ms/step - loss: 0.9211 - accuracy: 0.6078 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 2461/2461 [==============================] - 307s 125ms/step - loss: 0.9202 - accuracy: 0.6109 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 2461/2461 [==============================] - 306s 124ms/step - loss: 0.9075 - accuracy: 0.6168 - val_loss: 0.0530 - val_accuracy: 0.0000e+00
# Epoch 14/20
# 2461/2461 [==============================] - 306s 124ms/step - loss: 0.9016 - accuracy: 0.6184 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 15/20
# 2461/2461 [==============================] - 306s 124ms/step - loss: 0.9004 - accuracy: 0.6212 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 16/20
# 2461/2461 [==============================] - 307s 125ms/step - loss: 0.9029 - accuracy: 0.6206 - val_loss: 0.0539 - val_accuracy: 0.0000e+00
# Epoch 17/20
# 2461/2461 [==============================] - 306s 124ms/step - loss: 0.9005 - accuracy: 0.6212 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 18/20
# 2461/2461 [==============================] - 307s 125ms/step - loss: 0.9054 - accuracy: 0.6166 - val_loss: 0.0559 - val_accuracy: 0.0000e+00
# Epoch 19/20
# 2461/2461 [==============================] - 308s 125ms/step - loss: 0.8968 - accuracy: 0.6213 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 20/20
# 2461/2461 [==============================] - 308s 125ms/step - loss: 0.8961 - accuracy: 0.6236 - val_loss: 0.0556 - val_accuracy: 0.0000e+00
#
# ================================================================================
# Saving model bert_baseline...
# ================================================================================

# %%
#======================================================================
# Run Model Diagnostics
#======================================================================

use_report = run_model_diagnostics(use0, evD_use, evL, dvSen)
bert_report = run_model_diagnostics(bert0, evD_bert, evL, dvSen)

use_report.to_pickle("scratch/use_report.pkl")
bert_report.to_pickle("scratch/bert_report.pkl")

# %% [markdown]
# # First Order Theory of Mind

# %%
#======================================================================
# Load Models
#======================================================================

# Load model weights
use0, _ = load_model_and_history("use_baseline")
bert0, _ = load_model_and_history("bert_baseline")

# %%
#======================================================================
# Use predictions from other model as labels
#======================================================================


# Get temperature softened training and evaulation labels
trL_bert_softened = get_soft_predictions(bert0, trD_bert, TEMPERATURE)
evL_bert_softened = get_soft_predictions(bert0, evD_bert, TEMPERATURE)

trL_use_softened = get_soft_predictions(use0, trD_use, TEMPERATURE)
evL_use_softened = get_soft_predictions(use0, evD_use, TEMPERATURE)

# %%
#======================================================================
# Use predictions from other model as labels
#======================================================================

def get_soft_predictions(teacher, data, temperature, col = "logits"):
    '''Computes softened predictions from teacher model on input data.'''
    temp = tf.keras.models.Model(inputs = teacher.input, outputs = teacher.get_layer(col).output)
    preds = temp.predict(data) / temperature
    return np.apply_along_axis(lambda preds: np.exp(preds) / np.sum(np.exp(preds)), 1, preds)


def adjust_for_temperature(model, name, temperature, input_size = 512):
    # Build and compile model using loss weights 
    
    model.name_ = name
    model = add_distillation_arm(model, input_size)

    model.compile(loss = "categorical_crossentropy", 
                  optimizer = "adam",
                  loss_weights = {"distill_softmax": temperature ** 2, "softmax": 1},
                  metrics = ["acc"])
    
    return model

def add_distillation_arm(model, temperature = 1, input_size = 512):
    '''Builds and compiles a default model.'''
    
    # Get model name, inputs, outputs, and output size
    name = model.name_
    input_col_size = 512
    output_col_size = 3
    
    # Get outputs of model "partition" layer, then add distillation layer
    partition = model.get_layer("partition")
    outputs = add_layer_for_dense(partition.output, name, 128)
    distill = add_distillation_layers(name, 
                                      outputs, 
                                      temperature, 
                                      output_col_size)
    
    return tf.keras.models.Model(name = name, 
                                 inputs =  model.input, 
                                 outputs = [model.output, distill])
    
    
def add_distillation_layers(name, outputs, temperature, output_col_size):
    '''Returns a set of layers for distillation learning.'''
    distill = layers.Dense(output_col_size, name = "distill_logits")(outputs)
    distill = layers.Activation('softmax',name = "distill_softmax")(distill)
    return distill

# %%
#======================================================================
# Use Predicts BERT
#======================================================================

# Add labels alongside other model meta-data
use1, _ = load_model_and_history("use_baseline")
use1 = adjust_for_temperature(use1, "use_order_1_temp_1", TEMPERATURE)
use1 = add_attributes(use1, "use_order_1_temp_1", trD_use, [trL, trL_bert_softened], evD_use, [evL, evL_bert_softened])

fit_model(use1, epochs = 20)
save_model_and_history(use1)

# %%
#======================================================================
# BERT Predicts USE
#======================================================================

# Add labels alongside other model meta-data
bert1, _ = load_model_and_history("bert_baseline")
bert1 = adjust_for_temperature(bert1, "bert_order_1_temp_1", TEMPERATURE, 768)
bert1 = add_attributes(bert1, "bert_order_1", trD_bert, [trL, trL_use_softened], evD_bert, [evL, evL_use_softened])

fit_model(bert1, epochs = 20)
save_model_and_history(bert1)
# Out:
# ================================================================================
# Running model bert_order_1...
# ================================================================================
#
# Epoch 1/20
# 616/616 [==============================] - 103s 168ms/step - loss: 1.8501 - softmax_loss: 0.8063 - distill_softmax_loss: 0.8929 - softmax_acc: 0.6408 - distill_softmax_acc: 0.6357 - val_loss: 0.1082 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 2/20
# 616/616 [==============================] - 101s 165ms/step - loss: 1.7108 - softmax_loss: 0.7932 - distill_softmax_loss: 0.8140 - softmax_acc: 0.6506 - distill_softmax_acc: 0.6810 - val_loss: 0.1023 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 3/20
# 616/616 [==============================] - 102s 165ms/step - loss: 1.6820 - softmax_loss: 0.7801 - distill_softmax_loss: 0.7975 - softmax_acc: 0.6580 - distill_softmax_acc: 0.6927 - val_loss: 0.1067 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 4/20
# 616/616 [==============================] - 102s 166ms/step - loss: 1.6779 - softmax_loss: 0.7749 - distill_softmax_loss: 0.7933 - softmax_acc: 0.6630 - distill_softmax_acc: 0.6971 - val_loss: 0.1114 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 5/20
# 616/616 [==============================] - 103s 167ms/step - loss: 1.6679 - softmax_loss: 0.7678 - distill_softmax_loss: 0.7885 - softmax_acc: 0.6653 - distill_softmax_acc: 0.7002 - val_loss: 0.1107 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 6/20
# 616/616 [==============================] - 102s 166ms/step - loss: 1.6624 - softmax_loss: 0.7655 - distill_softmax_loss: 0.7860 - softmax_acc: 0.6680 - distill_softmax_acc: 0.7028 - val_loss: 0.1094 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 7/20
# 616/616 [==============================] - 103s 167ms/step - loss: 1.6536 - softmax_loss: 0.7608 - distill_softmax_loss: 0.7828 - softmax_acc: 0.6692 - distill_softmax_acc: 0.7018 - val_loss: 0.1119 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 8/20
# 616/616 [==============================] - 102s 166ms/step - loss: 1.6451 - softmax_loss: 0.7564 - distill_softmax_loss: 0.7782 - softmax_acc: 0.6712 - distill_softmax_acc: 0.7067 - val_loss: 0.1083 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 9/20
# 616/616 [==============================] - 103s 167ms/step - loss: 1.6445 - softmax_loss: 0.7562 - distill_softmax_loss: 0.7788 - softmax_acc: 0.6714 - distill_softmax_acc: 0.7060 - val_loss: 0.1069 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 10/20
# 616/616 [==============================] - 104s 168ms/step - loss: 1.6299 - softmax_loss: 0.7485 - distill_softmax_loss: 0.7732 - softmax_acc: 0.6753 - distill_softmax_acc: 0.7108 - val_loss: 0.1057 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 11/20
# 616/616 [==============================] - 103s 167ms/step - loss: 1.6280 - softmax_loss: 0.7490 - distill_softmax_loss: 0.7727 - softmax_acc: 0.6764 - distill_softmax_acc: 0.7114 - val_loss: 0.1055 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 12/20
# 616/616 [==============================] - 104s 168ms/step - loss: 1.6262 - softmax_loss: 0.7473 - distill_softmax_loss: 0.7708 - softmax_acc: 0.6768 - distill_softmax_acc: 0.7111 - val_loss: 0.1083 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 13/20
# 616/616 [==============================] - 104s 169ms/step - loss: 1.6236 - softmax_loss: 0.7445 - distill_softmax_loss: 0.7701 - softmax_acc: 0.6786 - distill_softmax_acc: 0.7137 - val_loss: 0.1062 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 14/20
# 616/616 [==============================] - 105s 171ms/step - loss: 1.6210 - softmax_loss: 0.7444 - distill_softmax_loss: 0.7685 - softmax_acc: 0.6770 - distill_softmax_acc: 0.7130 - val_loss: 0.1070 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 15/20
# 616/616 [==============================] - 103s 167ms/step - loss: 1.6154 - softmax_loss: 0.7424 - distill_softmax_loss: 0.7666 - softmax_acc: 0.6789 - distill_softmax_acc: 0.7152 - val_loss: 0.1042 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 16/20
# 616/616 [==============================] - 104s 168ms/step - loss: 1.6109 - softmax_loss: 0.7401 - distill_softmax_loss: 0.7664 - softmax_acc: 0.6799 - distill_softmax_acc: 0.7154 - val_loss: 0.1067 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 17/20
# 616/616 [==============================] - 102s 166ms/step - loss: 1.6076 - softmax_loss: 0.7373 - distill_softmax_loss: 0.7642 - softmax_acc: 0.6824 - distill_softmax_acc: 0.7163 - val_loss: 0.1039 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 18/20
# 616/616 [==============================] - 103s 167ms/step - loss: 1.6001 - softmax_loss: 0.7343 - distill_softmax_loss: 0.7619 - softmax_acc: 0.6824 - distill_softmax_acc: 0.7189 - val_loss: 0.1048 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 19/20
# 616/616 [==============================] - 104s 168ms/step - loss: 1.6002 - softmax_loss: 0.7336 - distill_softmax_loss: 0.7618 - softmax_acc: 0.6857 - distill_softmax_acc: 0.7194 - val_loss: 0.1059 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 20/20
# 616/616 [==============================] - 103s 167ms/step - loss: 1.5970 - softmax_loss: 0.7330 - distill_softmax_loss: 0.7598 - softmax_acc: 0.6836 - distill_softmax_acc: 0.7197 - val_loss: 0.1027 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
#
# ================================================================================
# Saving model bert_order_1...
# ================================================================================

# %%
#======================================================================
# Run Model Diagnostics
#======================================================================

use1, _ = load_model_and_history("use_order_1_temp_1")
use1.name_ = "use_order_1_temp_1"

use_report = run_model_diagnostics(use1, evD_use, evL, dvSen)
bert_report = run_model_diagnostics(bert1, evD_bert, evL, dvSen)

use_report.to_pickle("scratch/use_tom_1_report.pkl")
bert_report.to_pickle("scratch/bert_tom1_report.pkl")
# Out:
# ================================================================================
# use_order_1_temp_1
# ================================================================================
#
#                precision    recall  f1-score   support
#
# contradiction       0.84      0.74      0.79      3278
#    entailment       0.78      0.84      0.81      3329
#       neutral       0.72      0.75      0.74      3235
#
#      accuracy                           0.78      9842
#     macro avg       0.78      0.78      0.78      9842
#  weighted avg       0.78      0.78      0.78      9842
#
# Index(['neutral', 'entailment', 'contradiction'], dtype='object')
# [[0.24730746 0.03078643 0.0549685 ]
#  [0.01442796 0.28449502 0.03932128]
#  [0.03322495 0.0473481  0.2481203 ]]
#
# ================================================================================
# bert_order_1
# ================================================================================
#
#                precision    recall  f1-score   support
#
# contradiction       0.77      0.59      0.67      3278
#    entailment       0.63      0.83      0.72      3329
#       neutral       0.69      0.63      0.66      3235
#
#      accuracy                           0.69      9842
#     macro avg       0.70      0.68      0.68      9842
#  weighted avg       0.70      0.69      0.68      9842
#
# Index(['neutral', 'entailment', 'contradiction'], dtype='object')
# [[0.19579354 0.08169071 0.05557813]
#  [0.02011786 0.28104044 0.03708596]
#  [0.03871164 0.08128429 0.20869742]]

# %% [markdown]
# # Second-Order Theory of Mind

# %%
# Get temperature softened training and evaulation labels

bert1, _ = load_model_and_history("bert_order_1")
bert1.name_ = "bert_order_1"

use1, _ = load_model_and_history("use_order_1_temp_1")
use1.name_ = "use_order_1_temp_1"

trL_bert_softened = get_soft_predictions(bert1, trD_bert, TEMPERATURE)
evL_bert_softened = get_soft_predictions(bert1, evD_bert, TEMPERATURE)

trL_use_softened = get_soft_predictions(use1, trD_use, TEMPERATURE)
evL_use_softened = get_soft_predictions(use1, evD_use, TEMPERATURE)

# %%
#======================================================================
# Use Predicts BERT
#======================================================================

# Add labels alongside other model meta-data
use2, _ = load_model_and_history("use_baseline")
use2 = adjust_for_temperature(use2, "use_order_2_temp_1", TEMPERATURE, 512)
use2 = add_attributes(use2, "use_order_2_temp_1", trD_use, [trL, trL_bert_softened], evD_use, [evL, evL_bert_softened])

fit_model(use2, epochs = 20)
save_model_and_history(use2)
# Out:
# ================================================================================
# Running model use_order_2_temp_1...
# ================================================================================
#
# Epoch 1/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.5003 - softmax_loss: 0.3742 - distill_softmax_loss: 0.9042 - softmax_acc: 0.8554 - distill_softmax_acc: 0.7505 - val_loss: 0.2028 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 2/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.4061 - softmax_loss: 0.3509 - distill_softmax_loss: 0.8570 - softmax_acc: 0.8647 - distill_softmax_acc: 0.7831 - val_loss: 0.1930 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 3/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3861 - softmax_loss: 0.3396 - distill_softmax_loss: 0.8548 - softmax_acc: 0.8691 - distill_softmax_acc: 0.7837 - val_loss: 0.1891 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 4/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3741 - softmax_loss: 0.3324 - distill_softmax_loss: 0.8532 - softmax_acc: 0.8716 - distill_softmax_acc: 0.7861 - val_loss: 0.1872 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 5/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3667 - softmax_loss: 0.3267 - distill_softmax_loss: 0.8524 - softmax_acc: 0.8745 - distill_softmax_acc: 0.7870 - val_loss: 0.1857 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 6/20
# 616/616 [==============================] - 37s 61ms/step - loss: 1.3576 - softmax_loss: 0.3201 - distill_softmax_loss: 0.8519 - softmax_acc: 0.8768 - distill_softmax_acc: 0.7873 - val_loss: 0.1848 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 7/20
# 616/616 [==============================] - 38s 61ms/step - loss: 1.3541 - softmax_loss: 0.3161 - distill_softmax_loss: 0.8519 - softmax_acc: 0.8784 - distill_softmax_acc: 0.7891 - val_loss: 0.1858 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 8/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3483 - softmax_loss: 0.3106 - distill_softmax_loss: 0.8514 - softmax_acc: 0.8811 - distill_softmax_acc: 0.7880 - val_loss: 0.1860 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 9/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3458 - softmax_loss: 0.3070 - distill_softmax_loss: 0.8515 - softmax_acc: 0.8828 - distill_softmax_acc: 0.7892 - val_loss: 0.1876 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 10/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3427 - softmax_loss: 0.3031 - distill_softmax_loss: 0.8510 - softmax_acc: 0.8845 - distill_softmax_acc: 0.7888 - val_loss: 0.1880 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 11/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3382 - softmax_loss: 0.2986 - distill_softmax_loss: 0.8507 - softmax_acc: 0.8859 - distill_softmax_acc: 0.7891 - val_loss: 0.1881 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 12/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3406 - softmax_loss: 0.2998 - distill_softmax_loss: 0.8510 - softmax_acc: 0.8868 - distill_softmax_acc: 0.7883 - val_loss: 0.1893 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 13/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3412 - softmax_loss: 0.2984 - distill_softmax_loss: 0.8512 - softmax_acc: 0.8851 - distill_softmax_acc: 0.7888 - val_loss: 0.1914 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 14/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3337 - softmax_loss: 0.2915 - distill_softmax_loss: 0.8508 - softmax_acc: 0.8886 - distill_softmax_acc: 0.7884 - val_loss: 0.1913 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 15/20
# 616/616 [==============================] - 38s 61ms/step - loss: 1.3357 - softmax_loss: 0.2915 - distill_softmax_loss: 0.8508 - softmax_acc: 0.8894 - distill_softmax_acc: 0.7885 - val_loss: 0.1924 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 16/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3291 - softmax_loss: 0.2863 - distill_softmax_loss: 0.8502 - softmax_acc: 0.8908 - distill_softmax_acc: 0.7891 - val_loss: 0.1925 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 17/20
# 616/616 [==============================] - 39s 63ms/step - loss: 1.3288 - softmax_loss: 0.2855 - distill_softmax_loss: 0.8505 - softmax_acc: 0.8907 - distill_softmax_acc: 0.7899 - val_loss: 0.1925 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 18/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3281 - softmax_loss: 0.2839 - distill_softmax_loss: 0.8507 - softmax_acc: 0.8912 - distill_softmax_acc: 0.7890 - val_loss: 0.1937 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 19/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3240 - softmax_loss: 0.2798 - distill_softmax_loss: 0.8498 - softmax_acc: 0.8948 - distill_softmax_acc: 0.7893 - val_loss: 0.1945 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 20/20
# 616/616 [==============================] - 37s 60ms/step - loss: 1.3311 - softmax_loss: 0.2846 - distill_softmax_loss: 0.8503 - softmax_acc: 0.8918 - distill_softmax_acc: 0.7894 - val_loss: 0.1954 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
#
# ================================================================================
# Saving model use_order_2_temp_1...
# ================================================================================

# %%
#======================================================================
# BERT Predicts USE
#======================================================================

def add_layer_for_dense(inputs, name, nodes, activation = "relu", dropout = 0.2):
    '''Add a dense layer with a size specified by nodes.'''
    
    init = initializers.glorot_normal()
    k_regs = regularizers.l1_l2(l1=1e-5, l2=1e-4)
    
    x = layers.Dense(nodes, 
                     activation = activation, 
                     kernel_initializer = init,
                     kernel_regularizer= k_regs, name = "dense_layer_500")(inputs)
    x = layers.BatchNormalization(name = "tosst")(x)
    x = layers.Dropout(dropout, name = "temp")(x)
    return x

def fit_model(model, epochs = 5):
    '''Fits model with training and validation data.'''
    
    banner("Running model {}...".format(model.name_), symbol = "=")
    
    history = model.fit(model.trD_, 
                        model.trL_, 
                        validation_data=[model.evD_, model.evL_], 
                        batch_size = 128,
                        epochs=epochs, 
                        verbose=1)
    return history

# Add labels alongside other model meta-data
bert2, _ = load_model_and_history("bert_baseline")
bert2 = adjust_for_temperature(bert2, "bert_order_2_temp_1", TEMPERATURE, 768)
bert2 = add_attributes(bert2, "bert_order_2", trD_bert, [trL, trL_use_softened], evD_bert, [evL, evL_use_softened])

fit_model(bert2, epochs = 20)
save_model_and_history(bert2)
# Out:
# ================================================================================
# Running model bert_order_2...
# ================================================================================
#
# Epoch 1/20
# 274/274 [==============================] - 45s 163ms/step - loss: 1.9439 - softmax_loss: 0.8103 - distill_softmax_loss: 0.9404 - softmax_acc: 0.6399 - distill_softmax_acc: 0.6174 - val_loss: 0.1399 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 2/20
# 274/274 [==============================] - 44s 161ms/step - loss: 1.7704 - softmax_loss: 0.7997 - distill_softmax_loss: 0.8469 - softmax_acc: 0.6482 - distill_softmax_acc: 0.6633 - val_loss: 0.1133 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 3/20
# 274/274 [==============================] - 44s 162ms/step - loss: 1.7240 - softmax_loss: 0.7923 - distill_softmax_loss: 0.8216 - softmax_acc: 0.6505 - distill_softmax_acc: 0.6811 - val_loss: 0.1081 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 4/20
# 274/274 [==============================] - 44s 162ms/step - loss: 1.6927 - softmax_loss: 0.7816 - distill_softmax_loss: 0.8044 - softmax_acc: 0.6573 - distill_softmax_acc: 0.6931 - val_loss: 0.1073 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 5/20
# 274/274 [==============================] - 44s 162ms/step - loss: 1.6797 - softmax_loss: 0.7751 - distill_softmax_loss: 0.7959 - softmax_acc: 0.6607 - distill_softmax_acc: 0.7012 - val_loss: 0.1105 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 6/20
# 274/274 [==============================] - 44s 161ms/step - loss: 1.6701 - softmax_loss: 0.7681 - distill_softmax_loss: 0.7905 - softmax_acc: 0.6663 - distill_softmax_acc: 0.7042 - val_loss: 0.1115 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 7/20
# 274/274 [==============================] - 44s 161ms/step - loss: 1.6628 - softmax_loss: 0.7624 - distill_softmax_loss: 0.7866 - softmax_acc: 0.6661 - distill_softmax_acc: 0.7058 - val_loss: 0.1151 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 8/20
# 274/274 [==============================] - 44s 161ms/step - loss: 1.6535 - softmax_loss: 0.7568 - distill_softmax_loss: 0.7811 - softmax_acc: 0.6717 - distill_softmax_acc: 0.7115 - val_loss: 0.1164 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 9/20
# 274/274 [==============================] - 44s 160ms/step - loss: 1.6495 - softmax_loss: 0.7522 - distill_softmax_loss: 0.7795 - softmax_acc: 0.6719 - distill_softmax_acc: 0.7147 - val_loss: 0.1193 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 10/20
# 274/274 [==============================] - 44s 161ms/step - loss: 1.6446 - softmax_loss: 0.7497 - distill_softmax_loss: 0.7754 - softmax_acc: 0.6766 - distill_softmax_acc: 0.7134 - val_loss: 0.1200 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 11/20
# 274/274 [==============================] - 44s 160ms/step - loss: 1.6447 - softmax_loss: 0.7483 - distill_softmax_loss: 0.7745 - softmax_acc: 0.6761 - distill_softmax_acc: 0.7153 - val_loss: 0.1233 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 12/20
# 274/274 [==============================] - 44s 160ms/step - loss: 1.6388 - softmax_loss: 0.7442 - distill_softmax_loss: 0.7711 - softmax_acc: 0.6790 - distill_softmax_acc: 0.7155 - val_loss: 0.1228 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 13/20
# 274/274 [==============================] - 44s 160ms/step - loss: 1.6322 - softmax_loss: 0.7387 - distill_softmax_loss: 0.7697 - softmax_acc: 0.6803 - distill_softmax_acc: 0.7179 - val_loss: 0.1260 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 14/20
# 274/274 [==============================] - 44s 160ms/step - loss: 1.6265 - softmax_loss: 0.7355 - distill_softmax_loss: 0.7672 - softmax_acc: 0.6827 - distill_softmax_acc: 0.7220 - val_loss: 0.1225 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 15/20
# 274/274 [==============================] - 44s 162ms/step - loss: 1.6225 - softmax_loss: 0.7322 - distill_softmax_loss: 0.7661 - softmax_acc: 0.6832 - distill_softmax_acc: 0.7203 - val_loss: 0.1246 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 16/20
# 274/274 [==============================] - 44s 160ms/step - loss: 1.6235 - softmax_loss: 0.7337 - distill_softmax_loss: 0.7649 - softmax_acc: 0.6823 - distill_softmax_acc: 0.7207 - val_loss: 0.1256 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 17/20
# 274/274 [==============================] - 44s 161ms/step - loss: 1.6153 - softmax_loss: 0.7274 - distill_softmax_loss: 0.7624 - softmax_acc: 0.6864 - distill_softmax_acc: 0.7223 - val_loss: 0.1265 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 18/20
# 274/274 [==============================] - 44s 160ms/step - loss: 1.6160 - softmax_loss: 0.7286 - distill_softmax_loss: 0.7612 - softmax_acc: 0.6874 - distill_softmax_acc: 0.7259 - val_loss: 0.1250 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 19/20
# 274/274 [==============================] - 44s 161ms/step - loss: 1.6072 - softmax_loss: 0.7237 - distill_softmax_loss: 0.7579 - softmax_acc: 0.6895 - distill_softmax_acc: 0.7257 - val_loss: 0.1274 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
# Epoch 20/20
# 274/274 [==============================] - 44s 160ms/step - loss: 1.6069 - softmax_loss: 0.7236 - distill_softmax_loss: 0.7571 - softmax_acc: 0.6890 - distill_softmax_acc: 0.7283 - val_loss: 0.1253 - val_softmax_loss: 0.0000e+00 - val_distill_softmax_loss: 0.0000e+00 - val_softmax_acc: 0.0000e+00 - val_distill_softmax_acc: 0.0000e+00
#
# ================================================================================
# Saving model bert_order_2...
# ================================================================================

# %%
#======================================================================
# Run Model Diagnostics
#======================================================================

use2, _ = load_model_and_history("use_order_2_temp_1")
use2.name_ = use2.name

use2_report = run_model_diagnostics(use2, evD_use, evL, dvSen)
bert2_report = run_model_diagnostics(bert2, evD_bert, evL, dvSen)

use_report.to_pickle("scratch/use_tom_2_report.pkl")
bert_report.to_pickle("scratch/bert_tom_2_report.pkl")
# Out:
# ================================================================================
# use_order_2_temp_1
# ================================================================================
#
#                precision    recall  f1-score   support
#
# contradiction       0.78      0.82      0.80      3278
#    entailment       0.83      0.78      0.81      3329
#       neutral       0.74      0.74      0.74      3235
#
#      accuracy                           0.78      9842
#     macro avg       0.78      0.78      0.78      9842
#  weighted avg       0.78      0.78      0.78      9842
#
# Index(['neutral', 'entailment', 'contradiction'], dtype='object')
# [[0.27474091 0.01869539 0.03962609]
#  [0.02631579 0.26427555 0.04765292]
#  [0.05151392 0.03454582 0.24263361]]
#
# ================================================================================
# bert_order_2
# ================================================================================
#
#                precision    recall  f1-score   support
#
# contradiction       0.81      0.44      0.57      3278
#    entailment       0.64      0.77      0.70      3329
#       neutral       0.59      0.74      0.66      3235
#
#      accuracy                           0.65      9842
#     macro avg       0.68      0.65      0.64      9842
#  weighted avg       0.68      0.65      0.64      9842
#
# Index(['neutral', 'entailment', 'contradiction'], dtype='object')
# [[0.14793741 0.08351961 0.10160536]
#  [0.01452957 0.26071937 0.06299533]
#  [0.02113392 0.06584028 0.24171916]]

# %% [markdown]
# # Model Analysis and Diagnostics

# %%
def run_model_diagnostics(model, data, labels, sentences, theory_of_mind_level):

    banner(model.name_)
    
    cols = labels.columns
    preds = model.predict(data)
    if isinstance(preds, list):
        preds = preds[0]
    pred_labels = cols[preds.argmax(axis=-1)]
    true = labels.idxmax(axis=1)

    # Print reports
    cr = classification_report(true, pred_labels, output_dict = True)
    cm = confusion_matrix(true, pred_labels, normalize = "all")
    print(classification_report(true, pred_labels))
    print(cols)
    print(cm)
    
    cr = pd.DataFrame(cr)
    cr["name"] = model.name_
    cr["tom_level"] = theory_of_mind_level
    cr["metric"] = cr.index
    cr = cr[cr["metric"] != "support"]
    
    # Build report dataframe
    report = pd.DataFrame({"true": true, "predicted": pred_labels}) 
    report["correct"] = (report["true"] == report["predicted"])
    
    
    # Add sentences
    report = pd.concat([sentences.reset_index() , report.reset_index() ], axis = 1)
    
    report["sentence1_length"] = report["sentence1"].apply(lambda row: len(str(row).split()))
    report["sentence2_length"] = report["sentence2"].apply(lambda row: len(str(row).split()))
    report["sentence_difference"] = report["sentence1_length"] - report["sentence2_length"]
    
    report["name"] = model.name_
    report["tom_level"] = theory_of_mind_level
    
    return report, cr, cm

# %%
# Load models
use0, _ = load_model_and_history("use_baseline")
bert0, _ = load_model_and_history("bert_baseline")

# %%
#======================================================================
# Zero-Order
#======================================================================

use0.name_ = "use"
bert0.name_ = "bert"

use0_report, use0_cr, use0_cm = run_model_diagnostics(use0, evD_use, evL, dvSen, 0)
bert0_report, bert0_cr, bert0_cm  = run_model_diagnostics(bert0, evD_bert, evL, dvSen, 0)
# Out:
# ================================================================================
# use
# ================================================================================
#
#                precision    recall  f1-score   support
#
# contradiction       0.79      0.80      0.80      3278
#    entailment       0.79      0.82      0.81      3329
#       neutral       0.76      0.72      0.74      3235
#
#      accuracy                           0.78      9842
#     macro avg       0.78      0.78      0.78      9842
#  weighted avg       0.78      0.78      0.78      9842
#
# Index(['neutral', 'entailment', 'contradiction'], dtype='object')
# [[0.26722211 0.02529974 0.04054054]
#  [0.02540134 0.27829709 0.03454582]
#  [0.04582402 0.04775452 0.23511481]]
#
# ================================================================================
# bert
# ================================================================================
#
#                precision    recall  f1-score   support
#
# contradiction       0.62      0.68      0.65      3278
#    entailment       0.65      0.74      0.69      3329
#       neutral       0.71      0.54      0.61      3235
#
#      accuracy                           0.65      9842
#     macro avg       0.66      0.65      0.65      9842
#  weighted avg       0.66      0.65      0.65      9842
#
# Index(['neutral', 'entailment', 'contradiction'], dtype='object')
# [[0.22668157 0.06126803 0.04511278]
#  [0.06096322 0.24954278 0.02773826]
#  [0.08006503 0.07081894 0.17780939]]

# %%
use1.name_ = "use"
bert1.name_ = "bert"

use1_report, use1_cr, use1_cm = run_model_diagnostics(use1, evD_use, evL, dvSen, 1)
bert1_report, bert1_cr, bert1_cm = run_model_diagnostics(bert1, evD_bert, evL, dvSen, 1)
# Out:
# ================================================================================
# use
# ================================================================================
#
#                precision    recall  f1-score   support
#
# contradiction       0.84      0.74      0.79      3278
#    entailment       0.78      0.84      0.81      3329
#       neutral       0.72      0.75      0.74      3235
#
#      accuracy                           0.78      9842
#     macro avg       0.78      0.78      0.78      9842
#  weighted avg       0.78      0.78      0.78      9842
#
# Index(['neutral', 'entailment', 'contradiction'], dtype='object')
# [[0.24730746 0.03078643 0.0549685 ]
#  [0.01442796 0.28449502 0.03932128]
#  [0.03322495 0.0473481  0.2481203 ]]
#
# ================================================================================
# bert
# ================================================================================
#
#                precision    recall  f1-score   support
#
# contradiction       0.77      0.59      0.67      3278
#    entailment       0.63      0.83      0.72      3329
#       neutral       0.69      0.63      0.66      3235
#
#      accuracy                           0.69      9842
#     macro avg       0.70      0.68      0.68      9842
#  weighted avg       0.70      0.69      0.68      9842
#
# Index(['neutral', 'entailment', 'contradiction'], dtype='object')
# [[0.19579354 0.08169071 0.05557813]
#  [0.02011786 0.28104044 0.03708596]
#  [0.03871164 0.08128429 0.20869742]]

# %%
use2.name_ = "use"
bert2.name_ = "bert"

use2_report, use2_cr, use2_cm = run_model_diagnostics(use2, evD_use, evL, dvSen, 2)
bert2_report, bert2_cr, bert2_cm = run_model_diagnostics(bert2, evD_bert, evL, dvSen, 2)
# Out:
# ================================================================================
# use
# ================================================================================
#
#                precision    recall  f1-score   support
#
# contradiction       0.78      0.82      0.80      3278
#    entailment       0.83      0.78      0.81      3329
#       neutral       0.74      0.74      0.74      3235
#
#      accuracy                           0.78      9842
#     macro avg       0.78      0.78      0.78      9842
#  weighted avg       0.78      0.78      0.78      9842
#
# Index(['neutral', 'entailment', 'contradiction'], dtype='object')
# [[0.27474091 0.01869539 0.03962609]
#  [0.02631579 0.26427555 0.04765292]
#  [0.05151392 0.03454582 0.24263361]]
#
# ================================================================================
# bert
# ================================================================================
#
#                precision    recall  f1-score   support
#
# contradiction       0.81      0.44      0.57      3278
#    entailment       0.64      0.77      0.70      3329
#       neutral       0.59      0.74      0.66      3235
#
#      accuracy                           0.65      9842
#     macro avg       0.68      0.65      0.64      9842
#  weighted avg       0.68      0.65      0.64      9842
#
# Index(['neutral', 'entailment', 'contradiction'], dtype='object')
# [[0.14793741 0.08351961 0.10160536]
#  [0.01452957 0.26071937 0.06299533]
#  [0.02113392 0.06584028 0.24171916]]

# %%
#======================================================================
# Assemble into one dataframe
#======================================================================

reports = pd.concat([use0_report, bert0_report, use1_report, bert1_report, use2_report, bert2_report], axis = 1)
reports.head(50)
# Out:
#    index                                          sentence1  \
# 0      0  Two women are embracing while holding to go pa...
# 1      1  Two women are embracing while holding to go pa...
# 2      2  Two women are embracing while holding to go pa...
# 3      3  Two young children in blue jerseys, one with t...
# 4      4  Two young children in blue jerseys, one with t...
# 5      5  Two young children in blue jerseys, one with t...
# 6      6  A man selling donuts to a customer during a wo...
# 7      7  A man selling donuts to a customer during a wo...
# 8      8  A man selling donuts to a customer during a wo...
# 9      9  Two young boys of opposing teams play football...
# 10    10  Two young boys of opposing teams play football...
# 11    11  Two young boys of opposing teams play football...
# 12    12  A man in a blue shirt standing in front of a g...
# 13    13  A man in a blue shirt standing in front of a g...
# 14    14  A man in a blue shirt standing in front of a g...
# 15    15  Under a blue sky with white clouds, a child re...
# 16    16  Under a blue sky with white clouds, a child re...
# 17    17  Under a blue sky with white clouds, a child re...
# 18    18  A woman is doing a cartwheel while wearing a b...
# 19    19  A woman is doing a cartwheel while wearing a b...
# 20    20  A woman is doing a cartwheel while wearing a b...
# 21    21           Two men on bicycles competing in a race.
# 22    22           Two men on bicycles competing in a race.
# 23    23           Two men on bicycles competing in a race.
# 24    24  A young boy in a field of flowers carrying a ball
# 25    25  A young boy in a field of flowers carrying a ball
# 26    26  A young boy in a field of flowers carrying a ball
# 27    27  Families waiting in line at an amusement park ...
# 28    28  Families waiting in line at an amusement park ...
# 29    29  Families waiting in line at an amusement park ...
# 30    30  A senior is waiting at the window of a restaur...
# 31    31  A senior is waiting at the window of a restaur...
# 32    32  A senior is waiting at the window of a restaur...
# 33    33  Man in a black suit, white shirt and black bow...
# 34    34  Man in a black suit, white shirt and black bow...
# 35    35  Man in a black suit, white shirt and black bow...
# 36    36  Two women having drinks and smoking cigarettes...
# 37    37  Two women having drinks and smoking cigarettes...
# 38    38  Two women having drinks and smoking cigarettes...
# 39    39  At an outdoor event in an Asian-themed area, a...
# 40    40  At an outdoor event in an Asian-themed area, a...
# 41    41  At an outdoor event in an Asian-themed area, a...
# 42    42            Two doctors perform surgery on patient.
# 43    43            Two doctors perform surgery on patient.
# 44    44            Two doctors perform surgery on patient.
# 45    45  A white dog with long hair jumps to catch a re...
# 46    46  A white dog with long hair jumps to catch a re...
# 47    47  A white dog with long hair jumps to catch a re...
# 48    48                      Kids are on a amusement ride.
# 49    49                      Kids are on a amusement ride.
#
#                                             sentence2          label index  \
# 0   The sisters are hugging goodbye while holding ...        neutral     0
# 1                     Two woman are holding packages.     entailment     1
# 2                The men are fighting outside a deli.  contradiction     2
# 3      Two kids in numbered jerseys wash their hands.     entailment     3
# 4            Two kids at a ballgame wash their hands.        neutral     4
# 5                 Two kids in jackets walk to school.  contradiction     5
# 6          A woman drinks her coffee in a small cafe.  contradiction     6
# 7   A man selling donuts to a customer during a wo...        neutral     7
# 8                 A man selling donuts to a customer.     entailment     8
# 9                                  boys play football     entailment     9
# 10                               dog eats out of bowl  contradiction    10
# 11                           boys scoring a touchdown        neutral    11
# 12                       A man is repainting a garage        neutral    12
# 13                      A man is wearing a blue shirt     entailment    13
# 14                     A man is wearing a black shirt  contradiction    14
# 15  A child is reaching to touch the propeller of ...     entailment    15
# 16  A child is reaching to touch the propeller out...        neutral    16
# 17                    A child is playing with a ball.  contradiction    17
# 18                      A woman is doing a cartwheel.     entailment    18
# 19                        A woman is fixing her home.  contradiction    19
# 20  A woman is doing a cartwheel and falls on her ...  contradiction    20
# 21                           People are riding bikes.     entailment    21
# 22             Men are riding bicycles on the street.        neutral    22
# 23                    A few people are catching fish.  contradiction    23
# 24                          boy leaving baseball game        neutral    24
# 25                                       boy in field     entailment    25
# 26                                        dog in pool  contradiction    26
# 27                        The restaurant is very bad.  contradiction    27
# 28        People are waiting in line at a restaurant.  contradiction    28
# 29                 People are waiting to see a movie.  contradiction    29
# 30              A person waits to be served his food.     entailment    30
# 31              A man is waiting in line for the bus.  contradiction    31
# 32  A man is looking to order a grilled cheese san...        neutral    32
# 33                                 A person in a suit     entailment    33
# 34                                  Nobody has a suit  contradiction    34
# 35                            A tall person in a suit        neutral    35
# 36                            Two women are at a bar.     entailment    36
# 37                          Three women are at a bar.  contradiction    37
# 38                    Women are celebrating at a bar.        neutral    38
# 39                   A single man is next to a camera  contradiction    39
# 40                                 A crowd is dancing        neutral    40
# 41                    A crowd is in front of a camera        neutral    41
# 42                     Two surgeons are having lunch.  contradiction    42
# 43                    Doctors are performing surgery.     entailment    43
# 44       Two doctors are performing surgery on a man.        neutral    44
# 45  A white dog with long hair is swimming underwa...  contradiction    45
# 46           An animal is jumping to catch an object.     entailment    46
# 47  A white chihuahua mix with long curly hair is ...        neutral    47
# 48           Kids ride their favorite amusement ride.        neutral    48
# 49       A car is broke down on the side of the road.  contradiction    49
#
#              true      predicted correct sentence1_length sentence2_length  \
# 0         neutral        neutral    True                9               14
# 1      entailment     entailment    True                9                5
# 2   contradiction  contradiction    True                9                7
# 3      entailment        neutral   False               32                8
# 4         neutral     entailment   False               32                8
# 5   contradiction        neutral   False               32                7
# 6   contradiction  contradiction    True               18                9
# 7         neutral     entailment   False               18               19
# 8      entailment     entailment    True               18                7
# 9      entailment     entailment    True               15                3
# 10  contradiction  contradiction    True               15                5
# 11        neutral        neutral    True               15                4
# 12        neutral  contradiction   False               17                6
# 13     entailment     entailment    True               17                7
# 14  contradiction  contradiction    True               17                7
# 15     entailment        neutral   False               25               11
# 16        neutral        neutral    True               25               11
# 17  contradiction        neutral   False               25                7
# 18     entailment  contradiction   False               17                6
# 19  contradiction  contradiction    True               17                6
# 20  contradiction  contradiction    True               17               11
# 21     entailment     entailment    True                8                4
# 22        neutral        neutral    True                8                7
# 23  contradiction        neutral   False                8                6
# 24        neutral        neutral    True               11                4
# 25     entailment     entailment    True               11                3
# 26  contradiction  contradiction    True               11                3
# 27  contradiction  contradiction    True               13                5
# 28  contradiction  contradiction    True               13                8
# 29  contradiction  contradiction    True               13                7
# 30     entailment     entailment    True               13                8
# 31  contradiction  contradiction    True               13                9
# 32        neutral        neutral    True               13               10
# 33     entailment     entailment    True               21                5
# 34  contradiction  contradiction    True               21                4
# 35        neutral        neutral    True               21                6
# 36     entailment     entailment    True               10                6
# 37  contradiction     entailment   False               10                6
# 38        neutral     entailment   False               10                6
# 39  contradiction  contradiction    True               23                8
# 40        neutral  contradiction   False               23                4
# 41        neutral     entailment   False               23                8
# 42  contradiction  contradiction    True                6                5
# 43     entailment     entailment    True                6                4
# 44        neutral        neutral    True                6                8
# 45  contradiction  contradiction    True               14                9
# 46     entailment     entailment    True               14                8
# 47        neutral        neutral    True               14               18
# 48        neutral        neutral    True                6                6
# 49  contradiction  contradiction    True                6               11
#
#     ...          label index           true      predicted correct  \
# 0   ...        neutral     0        neutral        neutral    True
# 1   ...     entailment     1     entailment     entailment    True
# 2   ...  contradiction     2  contradiction        neutral   False
# 3   ...     entailment     3     entailment        neutral   False
# 4   ...        neutral     4        neutral        neutral    True
# 5   ...  contradiction     5  contradiction  contradiction    True
# 6   ...  contradiction     6  contradiction  contradiction    True
# 7   ...        neutral     7        neutral        neutral    True
# 8   ...     entailment     8     entailment        neutral   False
# 9   ...     entailment     9     entailment     entailment    True
# 10  ...  contradiction    10  contradiction  contradiction    True
# 11  ...        neutral    11        neutral     entailment   False
# 12  ...        neutral    12        neutral        neutral    True
# 13  ...     entailment    13     entailment     entailment    True
# 14  ...  contradiction    14  contradiction     entailment   False
# 15  ...     entailment    15     entailment     entailment    True
# 16  ...        neutral    16        neutral        neutral    True
# 17  ...  contradiction    17  contradiction     entailment   False
# 18  ...     entailment    18     entailment        neutral   False
# 19  ...  contradiction    19  contradiction        neutral   False
# 20  ...  contradiction    20  contradiction  contradiction    True
# 21  ...     entailment    21     entailment     entailment    True
# 22  ...        neutral    22        neutral  contradiction   False
# 23  ...  contradiction    23  contradiction  contradiction    True
# 24  ...        neutral    24        neutral        neutral    True
# 25  ...     entailment    25     entailment     entailment    True
# 26  ...  contradiction    26  contradiction  contradiction    True
# 27  ...  contradiction    27  contradiction        neutral   False
# 28  ...  contradiction    28  contradiction     entailment   False
# 29  ...  contradiction    29  contradiction     entailment   False
# 30  ...     entailment    30     entailment     entailment    True
# 31  ...  contradiction    31  contradiction  contradiction    True
# 32  ...        neutral    32        neutral        neutral    True
# 33  ...     entailment    33     entailment     entailment    True
# 34  ...  contradiction    34  contradiction  contradiction    True
# 35  ...        neutral    35        neutral     entailment   False
# 36  ...     entailment    36     entailment     entailment    True
# 37  ...  contradiction    37  contradiction     entailment   False
# 38  ...        neutral    38        neutral        neutral    True
# 39  ...  contradiction    39  contradiction     entailment   False
# 40  ...        neutral    40        neutral     entailment   False
# 41  ...        neutral    41        neutral     entailment   False
# 42  ...  contradiction    42  contradiction        neutral   False
# 43  ...     entailment    43     entailment     entailment    True
# 44  ...        neutral    44        neutral        neutral    True
# 45  ...  contradiction    45  contradiction     entailment   False
# 46  ...     entailment    46     entailment     entailment    True
# 47  ...        neutral    47        neutral     entailment   False
# 48  ...        neutral    48        neutral        neutral    True
# 49  ...  contradiction    49  contradiction  contradiction    True
#
#    sentence1_length sentence2_length  sentence_difference  name tom_level
# 0                 9               14                   -5  bert         2
# 1                 9                5                    4  bert         2
# 2                 9                7                    2  bert         2
# 3                32                8                   24  bert         2
# 4                32                8                   24  bert         2
# 5                32                7                   25  bert         2
# 6                18                9                    9  bert         2
# 7                18               19                   -1  bert         2
# 8                18                7                   11  bert         2
# 9                15                3                   12  bert         2
# 10               15                5                   10  bert         2
# 11               15                4                   11  bert         2
# 12               17                6                   11  bert         2
# 13               17                7                   10  bert         2
# 14               17                7                   10  bert         2
# 15               25               11                   14  bert         2
# 16               25               11                   14  bert         2
# 17               25                7                   18  bert         2
# 18               17                6                   11  bert         2
# 19               17                6                   11  bert         2
# 20               17               11                    6  bert         2
# 21                8                4                    4  bert         2
# 22                8                7                    1  bert         2
# 23                8                6                    2  bert         2
# 24               11                4                    7  bert         2
# 25               11                3                    8  bert         2
# 26               11                3                    8  bert         2
# 27               13                5                    8  bert         2
# 28               13                8                    5  bert         2
# 29               13                7                    6  bert         2
# 30               13                8                    5  bert         2
# 31               13                9                    4  bert         2
# 32               13               10                    3  bert         2
# 33               21                5                   16  bert         2
# 34               21                4                   17  bert         2
# 35               21                6                   15  bert         2
# 36               10                6                    4  bert         2
# 37               10                6                    4  bert         2
# 38               10                6                    4  bert         2
# 39               23                8                   15  bert         2
# 40               23                4                   19  bert         2
# 41               23                8                   15  bert         2
# 42                6                5                    1  bert         2
# 43                6                4                    2  bert         2
# 44                6                8                   -2  bert         2
# 45               14                9                    5  bert         2
# 46               14                8                    6  bert         2
# 47               14               18                   -4  bert         2
# 48                6                6                    0  bert         2
# 49                6               11                   -5  bert         2
#
# [50 rows x 78 columns]

# %%
cr = pd.concat([use0_cr, bert0_cr, use1_cr, bert1_cr, use2_cr, bert2_cr])

# cr = cr[cr["metric"] == "precision"]
cols = ["name", "tom_level", "metric", "entailment", "neutral", "contradiction"]
cr = cr[cols].sort_values(["name", "tom_level"])
cr.head(50)
# Out:
#            name  tom_level     metric  entailment   neutral  contradiction
# precision  bert          0  precision    0.653887  0.709364       0.616469
# recall     bert          0     recall    0.737759  0.540958       0.680598
# f1-score   bert          0   f1-score    0.693296  0.613820       0.646948
# precision  bert          1  precision    0.632952  0.692515       0.768955
# recall     bert          1     recall    0.830880  0.634930       0.587858
# f1-score   bert          1   f1-score    0.718535  0.662474       0.666321
# precision  bert          2  precision    0.635778  0.594899       0.805755
# recall     bert          2     recall    0.770802  0.735394       0.444173
# f1-score   bert          2   f1-score    0.696809  0.657727       0.572665
# precision   use          0  precision    0.792076  0.757943       0.789553
# recall      use          0     recall    0.822770  0.715301       0.802318
# f1-score    use          0   f1-score    0.807131  0.736005       0.795884
# precision   use          1  precision    0.784533  0.724629       0.838443
# recall      use          1     recall    0.841093  0.754869       0.742526
# f1-score    use          1   f1-score    0.811830  0.739440       0.787575
# precision   use          2  precision    0.832320  0.735448       0.779251
# recall      use          2     recall    0.781316  0.738176       0.824893
# f1-score    use          2   f1-score    0.806012  0.736810       0.801423
